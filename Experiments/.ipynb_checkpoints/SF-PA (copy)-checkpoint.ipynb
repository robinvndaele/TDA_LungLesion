# %% [markdown]
# # Topological feature for lung tumor type classification (SF/PA cohort)

# %% [markdown]
# In this notebook, we will study the use of topological features for lung tumor type classification. We start by setting the working directory and importing the required libraries.

# %%
# Set working directory (change accordingly)
workdir = "/home/robin/Documents/Stanford_VSR/NMI/Code"

import os
import sys
os.chdir("/home/robin/Documents/Stanford_VSR/NMI/Code")
sys.path.insert(0, os.path.join(workdir, "Functions"))

# %%
# Topological feature extraction
import TDAfeatures as tf

# Our custom functions to conduct our feature comparison experiments
import CV_SF_PA
from CV_SF_PA import run_exps_class

# Handling arrays and data frames
import numpy as np
import pandas as pd 

# Obtaining p-values
import scipy

# %% [markdown]
# ## Loading the data
#
# We start by loading the meta data (including the annotated tumor type), the radiomic features, and the topological features.

# %% [markdown]
# ### Loading the tumor types

# %%
meta = pd.read_excel(os.path.join("Features", "SF-PA", "Meta.xlsx"), index_col=0)
meta = meta.loc[[p for p in meta.index if p.startswith("PA") or p.startswith("SF")],:]
meta.loc[:,["Diagnosis"]].head(5)
# Out:
#         Diagnosis
# Patient
# PA_001     Benign
# PA_002     Benign
# PA_003     Benign
# PA_004     Benign
# PA_006     Benign

# %% [markdown]
# ### Loading the radiomic features

# %%
X_rad_PA = pd.read_csv(os.path.join("Features", "SF-PA", "Radiomic-PA.csv"), index_col=0)
X_rad_SF = pd.read_csv(os.path.join("Features", "SF-PA", "Radiomic-SF.csv"), index_col=0)

X_rad =  pd.concat([X_rad_PA, X_rad_SF], axis=0)

del X_rad_PA, X_rad_SF

X_rad.head(5)
# Out:
#         original_shape_Elongation  original_shape_Flatness  \
# PA_001                   0.605672                 0.434971
# PA_002                   0.629704                 0.576293
# PA_003                   0.921953                 0.736933
# PA_006                   0.730354                 0.598227
# PA_007                   0.769291                 0.737189
#
#         original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# PA_001                       16.924440                       38.909364
# PA_002                        5.730105                        9.943039
# PA_003                       21.599440                       29.309906
# PA_006                        5.912898                        9.884036
# PA_007                        9.945531                       13.491164
#
#         original_shape_Maximum2DDiameterColumn  \
# PA_001                               46.360721
# PA_002                                9.656916
# PA_003                               33.814821
# PA_006                               11.319231
# PA_007                               14.419092
#
#         original_shape_Maximum2DDiameterRow  \
# PA_001                            30.162321
# PA_002                            10.339174
# PA_003                            35.744093
# PA_006                             9.519716
# PA_007                            15.422968
#
#         original_shape_Maximum2DDiameterSlice  \
# PA_001                              48.324465
# PA_002                               9.583878
# PA_003                              33.186376
# PA_006                              11.288995
# PA_007                              13.356241
#
#         original_shape_Maximum3DDiameter  original_shape_MeshVolume  \
# PA_001                         51.338529                5546.264648
# PA_002                         11.786427                 225.808440
# PA_003                         37.770528               12025.904109
# PA_006                         11.473475                 214.920044
# PA_007                         15.836129                 999.739437
#
#         original_shape_MinorAxisLength  ...  \
# PA_001                       23.566325  ...
# PA_002                        6.261175  ...
# PA_003                       27.022362  ...
# PA_006                        7.218842  ...
# PA_007                       10.378631  ...
#
#         original_gldm_LargeDependenceLowGrayLevelEmphasis  \
# PA_001                                           0.033035
# PA_002                                           0.052424
# PA_003                                           0.096633
# PA_006                                           0.075388
# PA_007                                           0.124417
#
#         original_gldm_LowGrayLevelEmphasis  \
# PA_001                            0.002518
# PA_002                            0.010117
# PA_003                            0.000953
# PA_006                            0.022753
# PA_007                            0.005763
#
#         original_gldm_SmallDependenceEmphasis  \
# PA_001                               0.307242
# PA_002                               0.354831
# PA_003                               0.159743
# PA_006                               0.468849
# PA_007                               0.274149
#
#         original_gldm_SmallDependenceHighGrayLevelEmphasis  \
# PA_001                                         195.264436
# PA_002                                          69.689027
# PA_003                                         159.668231
# PA_006                                         229.607131
# PA_007                                          67.335270
#
#         original_gldm_SmallDependenceLowGrayLevelEmphasis  \
# PA_001                                           0.001150
# PA_002                                           0.007439
# PA_003                                           0.000302
# PA_006                                           0.014640
# PA_007                                           0.003903
#
#         original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# PA_001                 0.439791                   0.001385
# PA_002                 0.147176                   0.019231
# PA_003                 0.456699                   0.000512
# PA_006                 0.048106                   0.022808
# PA_007                 0.317320                   0.004203
#
#         original_ngtdm_Complexity  original_ngtdm_Contrast  \
# PA_001                2049.893186                 0.125360
# PA_002                 559.154932                 0.446830
# PA_003                3964.548672                 0.015585
# PA_006                3464.115534                 1.099773
# PA_007                 829.156209                 0.249850
#
#         original_ngtdm_Strength
# PA_001                 1.339161
# PA_002                 3.649947
# PA_003                 3.700103
# PA_006                15.651324
# PA_007                 2.335415
#
# [5 rows x 105 columns]

# %% [markdown]
# ### Extracting the topological features
#
# The topological features are not stored. Rather, we can quickly obtain them through the stored diagrams, which may also be used to potentially explore other machine learning models. We start by loading these diagrams.

# %%
dgms = {"img_sub":{}, "img_sup":{}, "img_box_sub":{}, "img_box_sup":{}, "point_cloud":{}}

for patient in os.listdir(os.path.join("Diagram", "SF-PA")):
    
    if len(os.listdir(os.path.join("Diagram", "SF-PA", patient)) != 15:
        continue
    
    for dgm in os.listdir(os.path.join("Diagram", "SF-PA", patient)):
        
        dgmtype = "_".join(dgm.split("_")[:-1])
        dgmdim = dgm.split("_")[-1].replace(".npy", "")
        dgms[dgmtype].setdefault(patient, {})
        dgms[dgmtype][patient][dgmdim] = np.load(os.path.join("Diagram", "SF-PA", patient, dgm))

# %% [markdown]
# We can now obtain our data of topological feature vectors as follows.

# %%
X_top = dict()

for dgm_type in dgms.keys():
    for patient in dgms[dgm_type].keys():
        
        X_top[patient] = X_top.setdefault(patient, {})
        
        for dim in dgms[dgm_type][patient].keys():
            
            features = tf.persistence_statistics(dgms[dgm_type][patient][dim])
            for key in features.keys():
                new_key = dgm_type + "_" + dim + "_" + key
                X_top[patient][new_key] = features[key]
            
            del features

X_top = pd.DataFrame(X_top).transpose()            
X_top.head(5)
# Out:
#         img_sub_dgm2_min_birth  img_sub_dgm2_no_infinite_lifespans  \
# SF_138                   -37.0                                 0.0
# SF_099                  -564.0                                 8.0
# PA_111                   -22.0                                 1.0
# SF_140                  -937.0                                97.0
# PA_085                  -979.0                                 0.0
#
#         img_sub_dgm2_no_finite_lifespans  img_sub_dgm2_mean_finite_midlifes  \
# SF_138                             202.0                         105.289604
# SF_099                             762.0                          64.196850
# PA_111                             479.0                          36.387265
# SF_140                           13212.0                          14.552452
# PA_085                           11397.0                         -67.292402
#
#         img_sub_dgm2_mean_finite_lifespans  img_sub_dgm2_std_finite_midlifes  \
# SF_138                           16.202970                         34.440457
# SF_099                           13.296588                         32.723940
# PA_111                            8.987474                         15.339030
# SF_140                           31.587345                        191.644702
# PA_085                           20.020444                        312.422884
#
#         img_sub_dgm2_std_finite_lifespans  img_sub_dgm2_skew_finite_midlifes  \
# SF_138                          16.414899                           0.002625
# SF_099                          11.384417                          -8.542390
# PA_111                           8.033324                          -0.191061
# SF_140                          28.295495                          -2.821279
# PA_085                          29.462102                          -1.173713
#
#         img_sub_dgm2_skew_finite_lifespans  \
# SF_138                            2.224121
# SF_099                            1.542019
# PA_111                            1.562512
# SF_140                            2.119256
# PA_085                            4.354624
#
#         img_sub_dgm2_kurtosis_finite_midlifes  ...  \
# SF_138                               3.034862  ...
# SF_099                             152.562225  ...
# PA_111                              -0.125307  ...
# SF_140                               6.932240  ...
# PA_085                               0.469028  ...
#
#         point_cloud_dgm2_kurtosis_finite_lifespans  \
# SF_138                                   22.474623
# SF_099                                   13.750821
# PA_111                                    5.104158
# SF_140                                  104.287870
# PA_085                                   -2.000000
#
#         point_cloud_dgm2_median_finite_midlifes  \
# SF_138                                 3.448817
# SF_099                                 5.319809
# PA_111                                 3.479384
# SF_140                                10.681124
# PA_085                                47.387635
#
#         point_cloud_dgm2_median_finite_lifespans  \
# SF_138                                  0.179362
# SF_099                                  0.264368
# PA_111                                  0.104443
# SF_140                                  0.676721
# PA_085                                 25.494720
#
#         point_cloud_dgm2_Q1_finite_midlifes  \
# SF_138                             3.038327
# SF_099                             4.903261
# PA_111                             3.258472
# SF_140                            10.027158
# PA_085                            41.135733
#
#         point_cloud_dgm2_Q1_finite_lifespans  \
# SF_138                              0.069967
# SF_099                              0.102028
# PA_111                              0.050184
# SF_140                              0.313158
# PA_085                             12.807174
#
#         point_cloud_dgm2_Q3_finite_midlifes  \
# SF_138                             4.079365
# SF_099                             6.785983
# PA_111                             3.764763
# SF_140                            11.217973
# PA_085                            53.639536
#
#         point_cloud_dgm2_Q3_finite_lifespans  \
# SF_138                              0.292047
# SF_099                              0.582593
# PA_111                              0.212081
# SF_140                              1.058532
# PA_085                             38.182265
#
#         point_cloud_dgm2_IQR_finite_midlifes  \
# SF_138                              1.041038
# SF_099                              1.882722
# PA_111                              0.506290
# SF_140                              1.190815
# PA_085                             12.503803
#
#         point_cloud_dgm2_IQR_finite_lifespans  \
# SF_138                               0.222080
# SF_099                               0.480565
# PA_111                               0.161897
# SF_140                               0.745374
# PA_085                              25.375091
#
#         point_cloud_dgm2_entropy_finite_lifespans
# SF_138                                   1.887704
# SF_099                                   3.946821
# PA_111                                   0.394692
# SF_140                                   4.530362
# PA_085                                   0.016549
#
# [5 rows x 300 columns]

# %% [markdown]
# Some columns of our topological features are known to be constant in advance. For example, the filtration constructed from the image with boundary pixels will always end at one connected component with no higher-dimensional holes. We will discard these from our topological features. Notice that indeed only columns from which we know in advance they are constant are discarded below.

# %%
constant_features = []

for col in X_top.columns:
    values = np.unique(X_top[col])
    values = values[~np.isnan(values)]
    if len(values) == 1:
        constant_features.append(col)
        
X_top = X_top.drop(columns=constant_features)

print("Discarded features (with constant values):")
print("\n")
for f in constant_features:
    print(f)
# Out:
# Discarded features (with constant values):
#
#
# img_box_sub_dgm2_no_infinite_lifespans
# img_box_sub_dgm0_no_infinite_lifespans
# img_box_sub_dgm1_no_infinite_lifespans
# img_box_sup_dgm1_no_infinite_lifespans
# img_box_sup_dgm0_no_infinite_lifespans
# img_box_sup_dgm2_no_infinite_lifespans
# point_cloud_dgm0_min_birth
# point_cloud_dgm0_no_infinite_lifespans
# point_cloud_dgm1_no_infinite_lifespans
# point_cloud_dgm2_no_infinite_lifespans

# %% [markdown]
# ### Final preparations
#
# Finally, we ensure that the indexing of all dataframes is consistent.

# %%
missing_rad = np.setdiff1d(meta.index, X_rad.index)
missing_top = np.setdiff1d(meta.index, X_top.index)
patients = np.setdiff1d(meta.index, np.concatenate([missing_rad, missing_top]))

print("Number of patients: " + str(len(patients)) +
      " (" + str(len(meta.index) - len(patients)) + " omitted from study)")
print("Number of radiomic features: " + str(X_rad.shape[1]) + 
      " (missing rows for " + str(len(missing_rad)) + " patients)")
print("Number of topological features: " + str(X_top.shape[1]) 
      + " (missing rows for " + str(len(missing_top)) + " patients)")

meta = meta.loc[patients,:]
X_rad =  X_rad.loc[patients,:]
X_top = X_top.loc[patients,:]
# Out:
# Number of patients: 165 (27 omitted from study)
# Number of radiomic features: 105 (missing rows for 27 patients)
# Number of topological features: 290 (missing rows for 2 patients)

# %% [markdown]
# ## Analysis of our outcome by contrast
#
# Below we analyse the frequency of tumor types in our data. These will be used as our dependent variables. Note that some classes are overlapping, e.g., adenocarcinoma is a more specific case of malignant. We will also separate our analyses below for scans obtained with and without contrast material injected into the bloodstream.

# %%
all_classes = {"benign": dict(), "malignant": dict(), 
               "small cell": dict(), "non-small cell": dict(),
               "adeno": dict(), "squamous": dict(),
               "Total": dict()}
with_contrast = [p for p in meta.index if meta.loc[p, "Contrast"] == "Y"]
without_contrast = [p for p in meta.index if meta.loc[p, "Contrast"] == "N"]

all_classes["benign"]["Y"] = np.sum(meta.loc[with_contrast, "Diagnosis"] == "Benign")
all_classes["benign"]["N"] = np.sum(meta.loc[without_contrast, "Diagnosis"] == "Benign")
all_classes["malignant"]["Y"] = np.sum(meta.loc[with_contrast, "Diagnosis"] != "Benign")
all_classes["malignant"]["N"] = np.sum(meta.loc[without_contrast, "Diagnosis"] != "Benign")

all_classes["small cell"]["Y"] = np.sum(meta.loc[with_contrast, "Diagnosis"] == "Small cell lung cancer")
all_classes["small cell"]["N"] = np.sum(meta.loc[without_contrast, "Diagnosis"] == "Small cell lung cancer")
all_classes["non-small cell"]["Y"] = np.sum(~meta.loc[with_contrast, "Diagnosis"].isin(["Benign", "Small cell lung cancer"]))
all_classes["non-small cell"]["N"] = np.sum(~meta.loc[without_contrast, "Diagnosis"] .isin(["Benign", "Small cell lung cancer"]))

all_classes["adeno"]["Y"] = np.sum(meta.loc[with_contrast, "Diagnosis"] == "Adenocarcinoma")
all_classes["adeno"]["N"] = np.sum(meta.loc[without_contrast, "Diagnosis"] == "Adenocarcinoma")
all_classes["squamous"]["Y"] = np.sum(meta.loc[with_contrast, "Diagnosis"] == "Squamous cell carcinoma")
all_classes["squamous"]["N"] = np.sum(meta.loc[without_contrast, "Diagnosis"] == "Squamous cell carcinoma")

all_classes["Total"]["Y"] = len(with_contrast)
all_classes["Total"]["N"] = len(without_contrast)

all_classes = pd.DataFrame(all_classes).transpose()
all_classes["Total"] = all_classes["Y"] + all_classes["N"]

all_classes
# Out:
#                  Y    N  Total
# benign          22   63     85
# malignant       33   47     80
# small cell      17   10     27
# non-small cell  16   37     53
# adeno           11   20     31
# squamous         5   15     20
# Total           55  110    165

# %% [markdown]
# ## Evaluating features for tumor type prediction
#
# We now compare the effectivess of using radiomic features, topological features, and radiomic + topological  features (through concatenation or ensemble models) for the various binary classification problems one may consider within our data. These furthermore correspond to the main lung tumor classification that can be considered overall. All scores will be evaluated through the ROC AUC. The following function will be used to derive binary outcomes.

# %%
def get_patients_with_outcome(I, class0, class1):
    
    new_I = [patient for patient in I if meta.loc[patient, "Diagnosis"] in class0 + class1]
    y = np.array([0 if meta.loc[patient, "Diagnosis"] in class0 else 1 for patient in new_I]).astype("int")
    return new_I, y

# %% [markdown]
# A dictionary will be used to distinguish between categories of features that should be evaluated.

# %%
X_dict = {"rad": X_rad, "top": X_top}

# %% [markdown]
# Finally, the function below will be used to apply coloring to columns for visualization.

# %%
def grey(s):
    color = "lightgrey"
    return "background-color: %s" % color

# %% [markdown]
# ### Comparing features for Benign vs. Malignant classification
#
# We compare the effectivess of radiomic features, topological features, and radiomic + topological features, for **'benign'** vs. **'non-benign'** class prediction.

# %%
class0 = ["Benign"]
class1 = ["Small cell lung cancer", "Non-small cell lung cancer", "Adenocarcinoma", "Squamous cell carcinoma"]

# %% [markdown]
# #### Images with contrast

# %%
I, y = get_patients_with_outcome(with_contrast, class0, class1)

print("Calculating performances for tumor class prediction (class0 = {}, class1 = {})\n".format(class0, class1))

results, classifiers, results_summary = run_exps_class(X_dict={key:X_dict[key].loc[I,] for key in X_dict.keys()}, 
                                                       y=y, random_state=42)

p = scipy.stats.ttest_ind(results.loc[np.where(results["type"] == "rad")[0], "score"], 
                          results.loc[np.where(results["type"] == "vote_soft")[0], "score"])[1]
if results_summary.loc["mean", "vote_soft score"] > results_summary.loc["mean", "rad score"]:
    p /= 2
else:
    p = 1 - p/2

print("\np-value for difference in performance (rad >= vote): " + str(p))

results_summary.style.highlight_max(color="lightgreen", axis=1)\
    .applymap(grey, subset=[c for c in results_summary.columns if c.endswith("std")])
# Out:
# Calculating performances for tumor class prediction (class0 = ['Benign'], class1 = ['Small cell lung cancer', 'Non-small cell lung cancer', 'Adenocarcinoma', 'Squamous cell carcinoma'])
#
# Calculating performances for model: LR
# Calculating performances for model: RF
# Calculating performances for model: KNN
# Calculating performances for model: SVM
# Calculating performances for model: GNB
# Calculating performances for model: XGB
#
# p-value for difference in performance (rad >= vote): 5.660084124885129e-05
# <style  type="text/css" >
# #T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col1,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col3,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col5,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col7,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col9,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col1,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col3,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col5,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col7,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col9,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col1,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col3,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col5,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col7,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col9,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col1,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col3,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col5,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col7,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col9,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow4_col1,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow4_col3,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow4_col5,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow4_col7,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow4_col9,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow5_col1,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow5_col3,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow5_col5,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow5_col7,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow5_col9,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow6_col1,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow6_col3,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow6_col5,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow6_col7,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow6_col9{
#             background-color:  lightgrey;
#         }#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col6,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col6,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col6,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col6,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow4_col6,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow5_col2,#T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow6_col6{
#             background-color:  lightgreen;
#         }</style><table id="T_d04744e4_cd18_11eb_8665_9f9ebb1985fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rad score</th>        <th class="col_heading level0 col1" >rad std</th>        <th class="col_heading level0 col2" >top score</th>        <th class="col_heading level0 col3" >top std</th>        <th class="col_heading level0 col4" >concat score</th>        <th class="col_heading level0 col5" >concat std</th>        <th class="col_heading level0 col6" >vote_soft score</th>        <th class="col_heading level0 col7" >vote_soft std</th>        <th class="col_heading level0 col8" >stack score</th>        <th class="col_heading level0 col9" >stack std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d04744e4_cd18_11eb_8665_9f9ebb1985felevel0_row0" class="row_heading level0 row0" >LR</th>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col0" class="data row0 col0" >0.867048</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col1" class="data row0 col1" >0.086591</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col2" class="data row0 col2" >0.874571</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col3" class="data row0 col3" >0.109413</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col4" class="data row0 col4" >0.871524</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col5" class="data row0 col5" >0.107239</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col6" class="data row0 col6" >0.889381</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col7" class="data row0 col7" >0.091627</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col8" class="data row0 col8" >0.888524</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow0_col9" class="data row0 col9" >0.091840</td>
#             </tr>
#             <tr>
#                         <th id="T_d04744e4_cd18_11eb_8665_9f9ebb1985felevel0_row1" class="row_heading level0 row1" >RF</th>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col0" class="data row1 col0" >0.856738</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col1" class="data row1 col1" >0.119588</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col2" class="data row1 col2" >0.879262</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col3" class="data row1 col3" >0.110090</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col4" class="data row1 col4" >0.874786</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col5" class="data row1 col5" >0.116265</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col6" class="data row1 col6" >0.888071</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col7" class="data row1 col7" >0.113846</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col8" class="data row1 col8" >0.866119</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow1_col9" class="data row1 col9" >0.115742</td>
#             </tr>
#             <tr>
#                         <th id="T_d04744e4_cd18_11eb_8665_9f9ebb1985felevel0_row2" class="row_heading level0 row2" >KNN</th>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col0" class="data row2 col0" >0.839143</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col1" class="data row2 col1" >0.115059</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col2" class="data row2 col2" >0.871786</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col3" class="data row2 col3" >0.106304</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col4" class="data row2 col4" >0.878333</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col5" class="data row2 col5" >0.099574</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col6" class="data row2 col6" >0.879381</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col7" class="data row2 col7" >0.105863</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col8" class="data row2 col8" >0.837190</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow2_col9" class="data row2 col9" >0.105378</td>
#             </tr>
#             <tr>
#                         <th id="T_d04744e4_cd18_11eb_8665_9f9ebb1985felevel0_row3" class="row_heading level0 row3" >SVM</th>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col0" class="data row3 col0" >0.844190</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col1" class="data row3 col1" >0.099208</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col2" class="data row3 col2" >0.849881</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col3" class="data row3 col3" >0.115988</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col4" class="data row3 col4" >0.844190</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col5" class="data row3 col5" >0.116707</td>
#                         <td id="T_d04744e4_cd18_11eb_8665_9f9ebb1985ferow3_col6" class="data row3 col6" >0.880190</td>
#                         <td id="T_d04744e4_

# %% [markdown]
# #### Images without contrast

# %%
I, y = get_patients_with_outcome(without_contrast, class0, class1)

print("Calculating performances for tumor class prediction (class0 = {}, class1 = {})\n".format(class0, class1))

results, classifiers, results_summary = run_exps_class(X_dict={key:X_dict[key].loc[I,] for key in X_dict.keys()}, 
                                                       y=y, random_state=42)

p = scipy.stats.ttest_ind(results.loc[np.where(results["type"] == "rad")[0], "score"], 
                          results.loc[np.where(results["type"] == "vote_soft")[0], "score"])[1]
if results_summary.loc["mean", "vote_soft score"] > results_summary.loc["mean", "rad score"]:
    p /= 2
else:
    p = 1 - p/2

print("\np-value for difference in performance (rad >= vote): " + str(p))

results_summary.style.highlight_max(color="lightgreen", axis=1)\
    .applymap(grey, subset=[c for c in results_summary.columns if c.endswith("std")])
# Out:
# Calculating performances for tumor class prediction (class0 = ['Benign'], class1 = ['Small cell lung cancer', 'Non-small cell lung cancer', 'Adenocarcinoma', 'Squamous cell carcinoma'])
#
# Calculating performances for model: LR
# Calculating performances for model: RF
# Calculating performances for model: KNN
# Calculating performances for model: SVM
# Calculating performances for model: GNB
# Calculating performances for model: XGB
#
# p-value for difference in performance (rad >= vote): 1.030755413755527e-08
# <style  type="text/css" >
# #T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col1,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col3,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col5,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col7,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col9,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col1,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col3,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col5,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col7,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col9,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col1,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col3,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col5,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col7,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col9,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col1,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col3,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col5,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col7,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col9,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow4_col1,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow4_col3,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow4_col5,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow4_col7,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow4_col9,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow5_col1,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow5_col3,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow5_col5,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow5_col7,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow5_col9,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow6_col1,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow6_col3,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow6_col5,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow6_col7,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow6_col9{
#             background-color:  lightgrey;
#         }#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col6,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col6,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col6,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col6,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow4_col0,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow5_col6,#T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow6_col6{
#             background-color:  lightgreen;
#         }</style><table id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rad score</th>        <th class="col_heading level0 col1" >rad std</th>        <th class="col_heading level0 col2" >top score</th>        <th class="col_heading level0 col3" >top std</th>        <th class="col_heading level0 col4" >concat score</th>        <th class="col_heading level0 col5" >concat std</th>        <th class="col_heading level0 col6" >vote_soft score</th>        <th class="col_heading level0 col7" >vote_soft std</th>        <th class="col_heading level0 col8" >stack score</th>        <th class="col_heading level0 col9" >stack std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985felevel0_row0" class="row_heading level0 row0" >LR</th>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col0" class="data row0 col0" >0.755774</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col1" class="data row0 col1" >0.084026</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col2" class="data row0 col2" >0.781974</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col3" class="data row0 col3" >0.096893</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col4" class="data row0 col4" >0.785895</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col5" class="data row0 col5" >0.096132</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col6" class="data row0 col6" >0.801132</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col7" class="data row0 col7" >0.088010</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col8" class="data row0 col8" >0.796214</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow0_col9" class="data row0 col9" >0.089507</td>
#             </tr>
#             <tr>
#                         <th id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985felevel0_row1" class="row_heading level0 row1" >RF</th>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col0" class="data row1 col0" >0.732447</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col1" class="data row1 col1" >0.087133</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col2" class="data row1 col2" >0.752541</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col3" class="data row1 col3" >0.097828</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col4" class="data row1 col4" >0.764910</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col5" class="data row1 col5" >0.098194</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col6" class="data row1 col6" >0.786241</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col7" class="data row1 col7" >0.085062</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col8" class="data row1 col8" >0.695226</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow1_col9" class="data row1 col9" >0.094462</td>
#             </tr>
#             <tr>
#                         <th id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985felevel0_row2" class="row_heading level0 row2" >KNN</th>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col0" class="data row2 col0" >0.739778</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col1" class="data row2 col1" >0.102338</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col2" class="data row2 col2" >0.757682</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col3" class="data row2 col3" >0.094093</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col4" class="data row2 col4" >0.751985</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col5" class="data row2 col5" >0.103954</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col6" class="data row2 col6" >0.796410</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col7" class="data row2 col7" >0.092216</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col8" class="data row2 col8" >0.731641</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow2_col9" class="data row2 col9" >0.111014</td>
#             </tr>
#             <tr>
#                         <th id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985felevel0_row3" class="row_heading level0 row3" >SVM</th>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col0" class="data row3 col0" >0.750936</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col1" class="data row3 col1" >0.087415</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col2" class="data row3 col2" >0.768630</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col3" class="data row3 col3" >0.092457</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col4" class="data row3 col4" >0.773588</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col5" class="data row3 col5" >0.098372</td>
#                         <td id="T_fcb25a7e_cd1c_11eb_8665_9f9ebb1985ferow3_col6" class="data row3 col6" >0.796402</td>
#                         <td id="T_fcb25a7e_

# %% [markdown]
# ### Comparing features for Small vs. Non-small classification
#
# We compare the effectivess of radiomic features, topological features, and radiomic + topological features, for **'small cell'** vs. **'non-small cell'** class prediction.

# %%
class0 = ["Small cell lung cancer"]
class1 = ["Non-small cell lung cancer", "Adenocarcinoma", "Squamous cell carcinoma"]

# %% [markdown]
# #### Images with contrast

# %%
I, y = get_patients_with_outcome(with_contrast, class0, class1)

print("Calculating performances for tumor class prediction (class0 = {}, class1 = {})\n".format(class0, class1))

results, classifiers, results_summary = run_exps_class(X_dict={key:X_dict[key].loc[I,] for key in X_dict.keys()}, 
                                                       y=y, random_state=42)

p = scipy.stats.ttest_ind(results.loc[np.where(results["type"] == "rad")[0], "score"], 
                          results.loc[np.where(results["type"] == "vote_soft")[0], "score"])[1]
if results_summary.loc["mean", "vote_soft score"] > results_summary.loc["mean", "rad score"]:
    p /= 2
else:
    p = 1 - p/2

print("\np-value for difference in performance (rad >= vote): " + str(p))

results_summary.style.highlight_max(color="lightgreen", axis=1)\
    .applymap(grey, subset=[c for c in results_summary.columns if c.endswith("std")])
# Out:
# Calculating performances for tumor class prediction (class0 = ['Small cell lung cancer'], class1 = ['Non-small cell lung cancer', 'Adenocarcinoma', 'Squamous cell carcinoma'])
#
# Calculating performances for model: LR
# Calculating performances for model: RF
# Calculating performances for model: KNN
# Calculating performances for model: SVM
# Calculating performances for model: GNB
# Calculating performances for model: XGB
#
# p-value for difference in performance (rad >= vote): 0.9447426989966621
# <style  type="text/css" >
# #T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col0,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col0,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col6,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col0,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow4_col0,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow5_col0,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow6_col0{
#             background-color:  lightgreen;
#         }#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col1,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col3,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col5,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col7,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col9,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col1,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col3,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col5,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col7,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col9,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col1,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col3,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col5,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col7,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col9,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col1,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col3,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col5,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col7,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col9,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow4_col1,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow4_col3,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow4_col5,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow4_col7,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow4_col9,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow5_col1,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow5_col3,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow5_col5,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow5_col7,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow5_col9,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow6_col1,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow6_col3,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow6_col5,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow6_col7,#T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow6_col9{
#             background-color:  lightgrey;
#         }</style><table id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rad score</th>        <th class="col_heading level0 col1" >rad std</th>        <th class="col_heading level0 col2" >top score</th>        <th class="col_heading level0 col3" >top std</th>        <th class="col_heading level0 col4" >concat score</th>        <th class="col_heading level0 col5" >concat std</th>        <th class="col_heading level0 col6" >vote_soft score</th>        <th class="col_heading level0 col7" >vote_soft std</th>        <th class="col_heading level0 col8" >stack score</th>        <th class="col_heading level0 col9" >stack std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985felevel0_row0" class="row_heading level0 row0" >LR</th>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col0" class="data row0 col0" >0.797778</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col1" class="data row0 col1" >0.180708</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col2" class="data row0 col2" >0.625833</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col3" class="data row0 col3" >0.196701</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col4" class="data row0 col4" >0.621111</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col5" class="data row0 col5" >0.208667</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col6" class="data row0 col6" >0.756667</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col7" class="data row0 col7" >0.196463</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col8" class="data row0 col8" >0.744444</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow0_col9" class="data row0 col9" >0.210819</td>
#             </tr>
#             <tr>
#                         <th id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985felevel0_row1" class="row_heading level0 row1" >RF</th>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col0" class="data row1 col0" >0.783889</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col1" class="data row1 col1" >0.188422</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col2" class="data row1 col2" >0.631667</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col3" class="data row1 col3" >0.196305</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col4" class="data row1 col4" >0.737500</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col5" class="data row1 col5" >0.177131</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col6" class="data row1 col6" >0.760278</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col7" class="data row1 col7" >0.194103</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col8" class="data row1 col8" >0.771944</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow1_col9" class="data row1 col9" >0.199905</td>
#             </tr>
#             <tr>
#                         <th id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985felevel0_row2" class="row_heading level0 row2" >KNN</th>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col0" class="data row2 col0" >0.768333</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col1" class="data row2 col1" >0.173482</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col2" class="data row2 col2" >0.642222</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col3" class="data row2 col3" >0.195129</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col4" class="data row2 col4" >0.668333</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col5" class="data row2 col5" >0.192943</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col6" class="data row2 col6" >0.772222</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col7" class="data row2 col7" >0.189032</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col8" class="data row2 col8" >0.748333</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow2_col9" class="data row2 col9" >0.191156</td>
#             </tr>
#             <tr>
#                         <th id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985felevel0_row3" class="row_heading level0 row3" >SVM</th>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col0" class="data row3 col0" >0.798333</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col1" class="data row3 col1" >0.181201</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col2" class="data row3 col2" >0.625556</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col3" class="data row3 col3" >0.183585</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col4" class="data row3 col4" >0.608333</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col5" class="data row3 col5" >0.207907</td>
#                         <td id="T_44f472c0_cd1f_11eb_8665_9f9ebb1985ferow3_col6" class="data row3 col6" >0.750556</td>
#                         <td id="T_44f472c0_

# %% [markdown]
# #### Images without contrast

# %%
I, y = get_patients_with_outcome(without_contrast, class0, class1)

print("Calculating performances for tumor class prediction (class0 = {}, class1 = {})\n".format(class0, class1))

results, classifiers, results_summary = run_exps_class(X_dict={key:X_dict[key].loc[I,] for key in X_dict.keys()}, 
                                                       y=y, random_state=42)

p = scipy.stats.ttest_ind(results.loc[np.where(results["type"] == "rad")[0], "score"], 
                          results.loc[np.where(results["type"] == "vote_soft")[0], "score"])[1]
if results_summary.loc["mean", "vote_soft score"] > results_summary.loc["mean", "rad score"]:
    p /= 2
else:
    p = 1 - p/2

print("\np-value for difference in performance (rad >= vote): " + str(p))

results_summary.style.highlight_max(color="lightgreen", axis=1)\
    .applymap(grey, subset=[c for c in results_summary.columns if c.endswith("std")])
# Out:
# Calculating performances for tumor class prediction (class0 = ['Small cell lung cancer'], class1 = ['Non-small cell lung cancer', 'Adenocarcinoma', 'Squamous cell carcinoma'])
#
# Calculating performances for model: LR
# Calculating performances for model: RF
# Calculating performances for model: KNN
# Calculating performances for model: SVM
# Calculating performances for model: GNB
# Calculating performances for model: XGB
#
# p-value for difference in performance (rad >= vote): 0.0395000654001305
# <style  type="text/css" >
# #T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col1,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col3,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col5,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col7,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col9,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col1,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col3,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col5,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col7,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col9,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col1,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col3,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col5,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col7,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col9,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col1,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col3,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col5,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col7,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col9,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow4_col1,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow4_col3,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow4_col5,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow4_col7,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow4_col9,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow5_col1,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow5_col3,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow5_col5,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow5_col7,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow5_col9,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow6_col1,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow6_col3,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow6_col5,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow6_col7,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow6_col9{
#             background-color:  lightgrey;
#         }#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col6,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col6,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col6,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col6,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow4_col8,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow5_col6,#T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow6_col6{
#             background-color:  lightgreen;
#         }</style><table id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rad score</th>        <th class="col_heading level0 col1" >rad std</th>        <th class="col_heading level0 col2" >top score</th>        <th class="col_heading level0 col3" >top std</th>        <th class="col_heading level0 col4" >concat score</th>        <th class="col_heading level0 col5" >concat std</th>        <th class="col_heading level0 col6" >vote_soft score</th>        <th class="col_heading level0 col7" >vote_soft std</th>        <th class="col_heading level0 col8" >stack score</th>        <th class="col_heading level0 col9" >stack std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985felevel0_row0" class="row_heading level0 row0" >LR</th>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col0" class="data row0 col0" >0.803929</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col1" class="data row0 col1" >0.214895</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col2" class="data row0 col2" >0.797768</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col3" class="data row0 col3" >0.192174</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col4" class="data row0 col4" >0.816071</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col5" class="data row0 col5" >0.200000</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col6" class="data row0 col6" >0.825893</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col7" class="data row0 col7" >0.197200</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col8" class="data row0 col8" >0.816250</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow0_col9" class="data row0 col9" >0.201929</td>
#             </tr>
#             <tr>
#                         <th id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985felevel0_row1" class="row_heading level0 row1" >RF</th>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col0" class="data row1 col0" >0.838482</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col1" class="data row1 col1" >0.188954</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col2" class="data row1 col2" >0.816607</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col3" class="data row1 col3" >0.192662</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col4" class="data row1 col4" >0.843661</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col5" class="data row1 col5" >0.194384</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col6" class="data row1 col6" >0.868393</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col7" class="data row1 col7" >0.173123</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col8" class="data row1 col8" >0.837679</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow1_col9" class="data row1 col9" >0.176064</td>
#             </tr>
#             <tr>
#                         <th id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985felevel0_row2" class="row_heading level0 row2" >KNN</th>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col0" class="data row2 col0" >0.791071</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col1" class="data row2 col1" >0.184305</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col2" class="data row2 col2" >0.782946</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col3" class="data row2 col3" >0.190279</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col4" class="data row2 col4" >0.812946</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col5" class="data row2 col5" >0.186034</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col6" class="data row2 col6" >0.835893</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col7" class="data row2 col7" >0.192693</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col8" class="data row2 col8" >0.717857</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow2_col9" class="data row2 col9" >0.239542</td>
#             </tr>
#             <tr>
#                         <th id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985felevel0_row3" class="row_heading level0 row3" >SVM</th>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col0" class="data row3 col0" >0.779107</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col1" class="data row3 col1" >0.214366</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col2" class="data row3 col2" >0.773482</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col3" class="data row3 col3" >0.202446</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col4" class="data row3 col4" >0.807679</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col5" class="data row3 col5" >0.217690</td>
#                         <td id="T_e4699e0a_cd21_11eb_8665_9f9ebb1985ferow3_col6" class="data row3 col6" >0.814286</td>
#                         <td id="T_e4699e0a_

# %% [markdown]
# ### Comparing features for Adeno vs. Squamous classification
#
# We compare the effectivess of radiomic features, topological features, and radiomic + topological features, for **'adenocarcinoma'** vs. **'squamous cell carcinoma'** class prediction.

# %%
class0 = ["Adenocarcinoma"]
class1 = ["Squamous cell carcinoma"]

# %% [markdown]
# #### Images with contrast

# %%
I, y = get_patients_with_outcome(with_contrast, class0, class1)

print("Calculating performances for tumor class prediction (class0 = {}, class1 = {})\n".format(class0, class1))

results, classifiers, results_summary = run_exps_class(X_dict={key:X_dict[key].loc[I,] for key in X_dict.keys()}, 
                                                       y=y, random_state=42)

p = scipy.stats.ttest_ind(results.loc[np.where(results["type"] == "rad")[0], "score"], 
                          results.loc[np.where(results["type"] == "vote_soft")[0], "score"])[1]
if results_summary.loc["mean", "vote_soft score"] > results_summary.loc["mean", "rad score"]:
    p /= 2
else:
    p = 1 - p/2

print("\np-value for difference in performance (rad >= vote): " + str(p))

results_summary.style.highlight_max(color="lightgreen", axis=1)\
    .applymap(grey, subset=[c for c in results_summary.columns if c.endswith("std")])
# Out:
# Calculating performances for tumor class prediction (class0 = ['Adenocarcinoma'], class1 = ['Squamous cell carcinoma'])
#
# Calculating performances for model: LR
# Calculating performances for model: RF
# Calculating performances for model: KNN
# Calculating performances for model: SVM
# Calculating performances for model: GNB
# Calculating performances for model: XGB
#
# p-value for difference in performance (rad >= vote): 1.2420945946508668e-17
# <style  type="text/css" >
# #T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col1,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col3,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col5,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col7,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col1,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col3,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col5,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col7,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col1,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col3,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col5,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col7,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col1,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col3,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col5,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col7,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col1,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col3,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col5,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col7,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow5_col1,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow5_col3,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow5_col5,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow5_col7,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow6_col1,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow6_col3,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow6_col5,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow6_col7{
#             background-color:  lightgrey;
#         }#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col2,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col4,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col2,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col4,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col2,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col4,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col6,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow5_col2,#T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow6_col2{
#             background-color:  lightgreen;
#         }</style><table id="T_86b0a762_cd22_11eb_8665_9f9ebb1985fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rad score</th>        <th class="col_heading level0 col1" >rad std</th>        <th class="col_heading level0 col2" >top score</th>        <th class="col_heading level0 col3" >top std</th>        <th class="col_heading level0 col4" >concat score</th>        <th class="col_heading level0 col5" >concat std</th>        <th class="col_heading level0 col6" >vote_soft score</th>        <th class="col_heading level0 col7" >vote_soft std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86b0a762_cd22_11eb_8665_9f9ebb1985felevel0_row0" class="row_heading level0 row0" >LR</th>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col0" class="data row0 col0" >0.801667</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col1" class="data row0 col1" >0.280322</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col2" class="data row0 col2" >0.973333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col3" class="data row0 col3" >0.107290</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col4" class="data row0 col4" >0.973333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col5" class="data row0 col5" >0.107290</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col6" class="data row0 col6" >0.963333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow0_col7" class="data row0 col7" >0.160866</td>
#             </tr>
#             <tr>
#                         <th id="T_86b0a762_cd22_11eb_8665_9f9ebb1985felevel0_row1" class="row_heading level0 row1" >RF</th>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col0" class="data row1 col0" >0.668333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col1" class="data row1 col1" >0.375829</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col2" class="data row1 col2" >0.983333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col3" class="data row1 col3" >0.083333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col4" class="data row1 col4" >0.983333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col5" class="data row1 col5" >0.083333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col6" class="data row1 col6" >0.910000</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow1_col7" class="data row1 col7" >0.219114</td>
#             </tr>
#             <tr>
#                         <th id="T_86b0a762_cd22_11eb_8665_9f9ebb1985felevel0_row2" class="row_heading level0 row2" >KNN</th>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col0" class="data row2 col0" >0.545000</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col1" class="data row2 col1" >0.258849</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col2" class="data row2 col2" >0.896667</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col3" class="data row2 col3" >0.215742</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col4" class="data row2 col4" >0.871667</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col5" class="data row2 col5" >0.216801</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col6" class="data row2 col6" >0.860000</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow2_col7" class="data row2 col7" >0.250799</td>
#             </tr>
#             <tr>
#                         <th id="T_86b0a762_cd22_11eb_8665_9f9ebb1985felevel0_row3" class="row_heading level0 row3" >SVM</th>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col0" class="data row3 col0" >0.685000</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col1" class="data row3 col1" >0.332202</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col2" class="data row3 col2" >0.943333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col3" class="data row3 col3" >0.184421</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col4" class="data row3 col4" >0.970000</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col5" class="data row3 col5" >0.118743</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col6" class="data row3 col6" >0.966667</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow3_col7" class="data row3 col7" >0.152753</td>
#             </tr>
#             <tr>
#                         <th id="T_86b0a762_cd22_11eb_8665_9f9ebb1985felevel0_row4" class="row_heading level0 row4" >GNB</th>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col0" class="data row4 col0" >0.655000</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col1" class="data row4 col1" >0.328722</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col2" class="data row4 col2" >0.708333</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col3" class="data row4 col3" >0.271442</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col4" class="data row4 col4" >0.655000</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col5" class="data row4 col5" >0.295339</td>
#                         <td id="T_86b0a762_cd22_11eb_8665_9f9ebb1985ferow4_col6" class="data row4 col6" >0.730000</td>

# %% [markdown]
# #### Images without contrast

# %%
I, y = get_patients_with_outcome(without_contrast, class0, class1)

print("Calculating performances for tumor class prediction (class0 = {}, class1 = {})\n".format(class0, class1))

results, classifiers, results_summary = run_exps_class(X_dict={key:X_dict[key].loc[I,] for key in X_dict.keys()}, 
                                                       y=y, random_state=42)

p = scipy.stats.ttest_ind(results.loc[np.where(results["type"] == "rad")[0], "score"], 
                          results.loc[np.where(results["type"] == "vote_soft")[0], "score"])[1]
if results_summary.loc["mean", "vote_soft score"] > results_summary.loc["mean", "rad score"]:
    p /= 2
else:
    p = 1 - p/2

print("\np-value for difference in performance (rad >= vote): " + str(p))

results_summary.style.highlight_max(color="lightgreen", axis=1)\
    .applymap(grey, subset=[c for c in results_summary.columns if c.endswith("std")])
# Out:
# Calculating performances for tumor class prediction (class0 = ['Adenocarcinoma'], class1 = ['Squamous cell carcinoma'])
#
# Calculating performances for model: LR
# Calculating performances for model: RF
# Calculating performances for model: KNN
# Calculating performances for model: SVM
# Calculating performances for model: GNB
# Calculating performances for model: XGB
#
# p-value for difference in performance (rad >= vote): 3.759765833643999e-05
# <style  type="text/css" >
# #T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col1,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col3,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col5,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col7,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col9,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col1,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col3,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col5,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col7,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col9,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col1,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col3,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col5,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col7,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col9,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col1,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col3,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col5,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col7,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col9,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow4_col1,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow4_col3,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow4_col5,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow4_col7,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow4_col9,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow5_col1,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow5_col3,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow5_col5,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow5_col7,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow5_col9,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow6_col1,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow6_col3,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow6_col5,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow6_col7,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow6_col9{
#             background-color:  lightgrey;
#         }#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col6,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col6,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col6,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col4,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow4_col6,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow5_col2,#T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow6_col6{
#             background-color:  lightgreen;
#         }</style><table id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985fe" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rad score</th>        <th class="col_heading level0 col1" >rad std</th>        <th class="col_heading level0 col2" >top score</th>        <th class="col_heading level0 col3" >top std</th>        <th class="col_heading level0 col4" >concat score</th>        <th class="col_heading level0 col5" >concat std</th>        <th class="col_heading level0 col6" >vote_soft score</th>        <th class="col_heading level0 col7" >vote_soft std</th>        <th class="col_heading level0 col8" >stack score</th>        <th class="col_heading level0 col9" >stack std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985felevel0_row0" class="row_heading level0 row0" >LR</th>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col0" class="data row0 col0" >0.629167</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col1" class="data row0 col1" >0.223646</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col2" class="data row0 col2" >0.719167</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col3" class="data row0 col3" >0.169109</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col4" class="data row0 col4" >0.706667</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col5" class="data row0 col5" >0.178333</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col6" class="data row0 col6" >0.720833</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col7" class="data row0 col7" >0.185639</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col8" class="data row0 col8" >0.699167</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow0_col9" class="data row0 col9" >0.179368</td>
#             </tr>
#             <tr>
#                         <th id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985felevel0_row1" class="row_heading level0 row1" >RF</th>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col0" class="data row1 col0" >0.638333</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col1" class="data row1 col1" >0.255419</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col2" class="data row1 col2" >0.678333</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col3" class="data row1 col3" >0.139453</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col4" class="data row1 col4" >0.668333</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col5" class="data row1 col5" >0.176376</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col6" class="data row1 col6" >0.705833</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col7" class="data row1 col7" >0.158204</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col8" class="data row1 col8" >0.605833</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow1_col9" class="data row1 col9" >0.231272</td>
#             </tr>
#             <tr>
#                         <th id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985felevel0_row2" class="row_heading level0 row2" >KNN</th>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col0" class="data row2 col0" >0.642500</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col1" class="data row2 col1" >0.194024</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col2" class="data row2 col2" >0.710000</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col3" class="data row2 col3" >0.153650</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col4" class="data row2 col4" >0.698333</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col5" class="data row2 col5" >0.162780</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col6" class="data row2 col6" >0.741667</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col7" class="data row2 col7" >0.164359</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col8" class="data row2 col8" >0.679167</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow2_col9" class="data row2 col9" >0.179554</td>
#             </tr>
#             <tr>
#                         <th id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985felevel0_row3" class="row_heading level0 row3" >SVM</th>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col0" class="data row3 col0" >0.659167</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col1" class="data row3 col1" >0.219799</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col2" class="data row3 col2" >0.714167</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col3" class="data row3 col3" >0.172605</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col4" class="data row3 col4" >0.716667</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col5" class="data row3 col5" >0.169353</td>
#                         <td id="T_e04d6f7e_cd24_11eb_8665_9f9ebb1985ferow3_col6" class="data row3 col6" >0.715833</td>
#                         <td id="T_e04d6f7e_
